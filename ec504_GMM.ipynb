# %%
#refered from 
#https://github.com/laituan245/image-segmentation-GMM

# %%
import numpy as np
from PIL import Image

COLORS = [ 
    (255, 0, 0),   # red
    (0, 255, 0),  # green
    (0, 0, 255),   # blue
    (255, 255, 0), # yellow
    (255, 0, 255), # magenta
]

def load_image(infilename) :
    img = Image.open( infilename )
    img.load()
    data = np.asarray( img, dtype="int32" )
    return data

# %%
import numpy as np

#from utils import COLORS, load_image
from scipy.stats import multivariate_normal
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt


class GMM:
    def __init__(self, ncomp, initial_mus, initial_covs, initial_priors):
        self.ncomp = ncomp
        self.mus = np.asarray(initial_mus)
        self.covs = np.asarray(initial_covs)
        self.priors = np.asarray(initial_priors)

    def inference(self, datas): # E-step
        unnormalized_probs = []
        for i in range(self.ncomp):
            mu, cov, prior = self.mus[i, :], self.covs[i, :, :], self.priors[i]
            unnormalized_prob = prior * multivariate_normal.pdf(datas, mean=mu, cov=cov,allow_singular=1)
            unnormalized_probs.append(np.expand_dims(unnormalized_prob, -1))
        preds = np.concatenate(unnormalized_probs, axis=1)
        log_likelihood = np.sum(preds, axis=1)
        log_likelihood = np.sum(np.log(log_likelihood))

        preds = preds / np.sum(preds, axis=1, keepdims=True)
        return np.asarray(preds), log_likelihood

    def update(self, datas, beliefs): # M-step
        new_mus, new_covs, new_priors = [], [], []
        soft_counts = np.sum(beliefs, axis=0)
        for i in range(self.ncomp):
            new_mu = np.sum(np.expand_dims(beliefs[:, i], -1) * datas, axis=0)
            new_mu /= soft_counts[i]
            new_mus.append(new_mu)

            data_shifted = np.subtract(datas, np.expand_dims(new_mu, 0))
            new_cov = np.matmul(np.transpose(np.multiply(np.expand_dims(beliefs[:, i], -1), data_shifted)), data_shifted)
            new_cov /= soft_counts[i]
            new_covs.append(new_cov)

            new_priors.append(soft_counts[i] / np.sum(soft_counts))

        self.mus = np.asarray(new_mus)
        self.covs = np.asarray(new_covs)
        self.priors = np.asarray(new_priors)

if __name__ == '__main__':
    # Load image
    #image_name = raw_input('Input the image name: ')
    image_path = 'horse.jfif'
    image = load_image(image_path)
    image_height, image_width, image_channels = image.shape
    image_pixels = np.reshape(image, (-1, image_channels))
    _mean = np.mean(image_pixels,axis=0,keepdims=True)
    _std = np.std(image_pixels,axis=0,keepdims=True)
    image_pixels = (image_pixels - _mean) / _std # Normalization

    # Input number of classes
    #ncomp = int(input('Input number of classes: '))
    ncomp=5

    # Apply K-Means to find the initial weights and covariance matrices for GMM
    kmeans = KMeans(n_clusters=ncomp)
    labels = kmeans.fit_predict(image_pixels)
    initial_mus = kmeans.cluster_centers_
    initial_priors, initial_covs = [], []
    for i in range(ncomp):
        datas = np.array([image_pixels[j, :] for j in range(len(labels)) if labels[j] == i]).T
        initial_covs.append(np.cov(datas))
        initial_priors.append(datas.shape[1] / float(len(labels)))

    # Initialize a GMM
    gmm = GMM(ncomp, initial_mus, initial_covs, initial_priors)

    # EM Algorithm
    prev_log_likelihood = None
    for i in range(1000):
        beliefs, log_likelihood = gmm.inference(image_pixels) # E-step
        gmm.update(image_pixels, beliefs)   # M-step
        print('Iteration {}: Log Likelihood = {}'.format(i+1, log_likelihood))
        if prev_log_likelihood != None and abs(log_likelihood - prev_log_likelihood) < 1e-10:
            break
        prev_log_likelihood = log_likelihood

    # Show Result
    beliefs, log_likelihood = gmm.inference(image_pixels)
    map_beliefs = np.reshape(beliefs, (image_height, image_width, ncomp))
    segmented_map = np.zeros((image_height, image_width, 3))
    for i in range(image_height):
        for j in range(image_width):
            hard_belief = np.argmax(map_beliefs[i, j, :])
            segmented_map[i,j,:] = np.asarray(COLORS[hard_belief]) / 255.0
    plt.imshow(segmented_map)
    plt.show()
# Out:
# Iteration 1: Log Likelihood = -75488.02718899067
# Iteration 2: Log Likelihood = -66343.74106432626
# Iteration 3: Log Likelihood = -59863.57475055533
# Iteration 4: Log Likelihood = -55635.32968484613
# Iteration 5: Log Likelihood = -51729.64501784279
# Iteration 6: Log Likelihood = -49065.85420524773
# Iteration 7: Log Likelihood = -47236.804354260705
# Iteration 8: Log Likelihood = -45577.095394263815
# Iteration 9: Log Likelihood = -44328.24988139709
# Iteration 10: Log Likelihood = -43462.317675376136
# Iteration 11: Log Likelihood = -42916.85938856273
# Iteration 12: Log Likelihood = -42589.073353498745
# Iteration 13: Log Likelihood = -42357.8119040301
# Iteration 14: Log Likelihood = -42168.85162056513
# Iteration 15: Log Likelihood = -42012.68041246037
# Iteration 16: Log Likelihood = -41880.26831307011
# Iteration 17: Log Likelihood = -41762.78200710835
# Iteration 18: Log Likelihood = -41653.19095845244
# Iteration 19: Log Likelihood = -41557.528888358975
# Iteration 20: Log Likelihood = -41489.35088643784
# Iteration 21: Log Likelihood = -41444.03484446059
# Iteration 22: Log Likelihood = -41410.397240108745
# Iteration 23: Log Likelihood = -41382.35891415693
# Iteration 24: Log Likelihood = -41357.404400587984
# Iteration 25: Log Likelihood = -41335.326059913205
# Iteration 26: Log Likelihood = -41317.670489745986
# Iteration 27: Log Likelihood = -41305.06829092575
# Iteration 28: Log Likelihood = -41296.71158372508
# Iteration 29: Log Likelihood = -41291.37875539223
# Iteration 30: Log Likelihood = -41287.939131274674
# Iteration 31: Log Likelihood = -41285.632143726674
# Iteration 32: Log Likelihood = -41284.01887981001
# Iteration 33: Log Likelihood = -41282.84786602138
# Iteration 34: Log Likelihood = -41281.969242099934
# Iteration 35: Log Likelihood = -41281.29026262069
# Iteration 36: Log Likelihood = -41280.75188388089
# Iteration 37: Log Likelihood = -41280.31567543176
# Iteration 38: Log Likelihood = -41279.956106402235
# Iteration 39: Log Likelihood = -41279.65583461293
# Iteration 40: Log Likelihood = -41279.40276729436
# Iteration 41: Log Likelihood = -41279.18820621093
# Iteration 42: Log Likelihood = -41279.005671941355
# Iteration 43: Log Likelihood = -41278.85015880657
# Iteration 44: Log Likelihood = -41278.7176639647
# Iteration 45: Log Likelihood = -41278.60489056019
# Iteration 46: Log Likelihood = -41278.50906044543
# Iteration 47: Log Likelihood = -41278.42779500674
# Iteration 48: Log Likelihood = -41278.35903765669
# Iteration 49: Log Likelihood = -41278.301001389234
# Iteration 50: Log Likelihood = -41278.25213118372
# Iteration 51: Log Likelihood = -41278.211075141415
# Iteration 52: Log Likelihood = -41278.17666081121
# Iteration 53: Log Likelihood = -41278.147874736096
# Iteration 54: Log Likelihood = -41278.12384418418
# Iteration 55: Log Likelihood = -41278.1038205531
# Iteration 56: Log Likelihood = -41278.087164217985
# Iteration 57: Log Likelihood = -41278.07333072339
# Iteration 58: Log Likelihood = -41278.06185827488
# Iteration 59: Log Likelihood = -41278.05235649371
# Iteration 60: Log Likelihood = -41278.04449639019
# Iteration 61: Log Likelihood = -41278.03800149649
# Iteration 62: Log Likelihood = -41278.03264008493
# Iteration 63: Log Likelihood = -41278.028218387844
# Iteration 64: Log Likelihood = -41278.02457472846
# Iteration 65: Log Likelihood = -41278.02157446982
# Iteration 66: Log Likelihood = -41278.01910569183
# Iteration 67: Log Likelihood = -41278.0170755074
# Iteration 68: Log Likelihood = -41278.01540693819
# Iteration 69: Log Likelihood = -41278.01403627364
# Iteration 70: Log Likelihood = -41278.01291084695
# Iteration 71: Log Likelihood = -41278.01198716762
# Iteration 72: Log Likelihood = -41278.01122935747
# Iteration 73: Log Likelihood = -41278.01060784422
# Iteration 74: Log Likelihood = -41278.010098272505
# Iteration 75: Log Likelihood = -41278.009680598094
# Iteration 76: Log Likelihood = -41278.00933833517
# Iteration 77: Log Likelihood = -41278.00905793277
# Iteration 78: Log Likelihood = -41278.008828258244
# Iteration 79: Log Likelihood = -41278.00864016978
# Iteration 80: Log Likelihood = -41278.008486163955
# Iteration 81: Log Likelihood = -41278.008360084285
# Iteration 82: Log Likelihood = -41278.00825688125
# Iteration 83: Log Likelihood = -41278.0081724147
# Iteration 84: Log Likelihood = -41278.00810329093
# Iteration 85: Log Likelihood = -41278.00804672887
# Iteration 86: Log Likelihood = -41278.00800045002
# Iteration 87: Log Likelihood = -41278.007962588075
# Iteration 88: Log Likelihood = -41278.00793161461
# Iteration 89: Log Likelihood = -41278.00790627807
# Iteration 90: Log Likelihood = -41278.00788555389
# Iteration 91: Log Likelihood = -41278.00786860339
# Iteration 92: Log Likelihood = -41278.007854740135
# Iteration 93: Log Likelihood = -41278.007843402345
# Iteration 94: Log Likelihood = -41278.00783413034
# Iteration 95: Log Likelihood = -41278.007826548
# Iteration 96: Log Likelihood = -41278.00782034768
# Iteration 97: Log Likelihood = -41278.00781527758
# Iteration 98: Log Likelihood = -41278.00781113183
# Iteration 99: Log Likelihood = -41278.00780774198
# Iteration 100: Log Likelihood = -41278.00780497026
# Iteration 101: Log Likelihood = -41278.00780270404
# Iteration 102: Log Likelihood = -41278.00780085115
# Iteration 103: Log Likelihood = -41278.0077993362
# Iteration 104: Log Likelihood = -41278.00779809756
# Iteration 105: Log Likelihood = -41278.007797084894
# Iteration 106: Log Likelihood = -41278.007796256985
# Iteration 107: Log Likelihood = -41278.0077955801
# Iteration 108: Log Likelihood = -41278.007795026715
# Iteration 109: Log Likelihood = -41278.00779457435
# Iteration 110: Log Likelihood = -41278.0077942045
# Iteration 111: Log Likelihood = -41278.00779390209
# Iteration 112: Log Likelihood = -41278.00779365489
# Iteration 113: Log Likelihood = -41278.007793452765
# Iteration 114: Log Likelihood = -41278.00779328756
# Iteration 115: Log Likelihood = -41278.007793152494
# Iteration 116: Log Likelihood = -41278.007793042096
# Iteration 117: Log Likelihood = -41278.007792951845
# Iteration 118: Log Likelihood = -41278.00779287801
# Iteration 119: Log Likelihood = -41278.00779281771
# Iteration 120: Log Likelihood = -41278.0077927684
# Iteration 121: Log Likelihood = -41278.007792728095
# Iteration 122: Log Likelihood = -41278.007792695134
# Iteration 123: Log Likelihood = -41278.0077926682
# Iteration 124: Log Likelihood = -41278.007792646174
# Iteration 125: Log Likelihood = -41278.00779262818
# Iteration 126: Log Likelihood = -41278.007792613455
# Iteration 127: Log Likelihood = -41278.007792601406
# Iteration 128: Log Likelihood = -41278.00779259153
# Iteration 129: Log Likelihood = -41278.00779258353
# Iteration 130: Log Likelihood = -41278.00779257699
# Iteration 131: Log Likelihood = -41278.007792571574
# Iteration 132: Log Likelihood = -41278.00779256718
# Iteration 133: Log Likelihood = -41278.00779256359
# Iteration 134: Log Likelihood = -41278.00779256068
# Iteration 135: Log Likelihood = -41278.00779255827
# Iteration 136: Log Likelihood = -41278.00779255631
# Iteration 137: Log Likelihood = -41278.007792554694
# Iteration 138: Log Likelihood = -41278.00779255339
# Iteration 139: Log Likelihood = -41278.00779255232
# Iteration 140: Log Likelihood = -41278.00779255145
# Iteration 141: Log Likelihood = -41278.007792550714
# Iteration 142: Log Likelihood = -41278.00779255014
# Iteration 143: Log Likelihood = -41278.007792549644
# Iteration 144: Log Likelihood = -41278.00779254929
# Iteration 145: Log Likelihood = -41278.00779254896
# Iteration 146: Log Likelihood = -41278.007792548684
# Iteration 147: Log Likelihood = -41278.00779254847
# Iteration 148: Log Likelihood = -41278.007792548306
# Iteration 149: Log Likelihood = -41278.00779254816
# Iteration 150: Log Likelihood = -41278.00779254804
# Iteration 151: Log Likelihood = -41278.007792547935
# Iteration 152: Log Likelihood = -41278.007792547854
